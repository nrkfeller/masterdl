# %% [markdown]
# # 9 Improving performance

# %%
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt

# %% [markdown]
# ## Learning curves

# %%
from sklearn.datasets import load_digits

# %%
digits = load_digits()

# %%
X, y = digits.data, digits.target

# %%
X[0]
# Out:
# array([  0.,   0.,   5.,  13.,   9.,   1.,   0.,   0.,   0.,   0.,  13.,
#         15.,  10.,  15.,   5.,   0.,   0.,   3.,  15.,   2.,   0.,  11.,
#          8.,   0.,   0.,   4.,  12.,   0.,   0.,   8.,   8.,   0.,   0.,
#          5.,   8.,   0.,   0.,   9.,   8.,   0.,   0.,   4.,  11.,   0.,
#          1.,  12.,   7.,   0.,   0.,   2.,  14.,   5.,  10.,  12.,   0.,
#          0.,   0.,   0.,   6.,  13.,  10.,   0.,   0.,   0.])

# %%
X.shape
# Out:
# (1797, 64)

# %%
for i in range(8):
    plt.subplot(1,8,i+1)
    plt.imshow(X.reshape(-1, 8, 8)[i], cmap='gray')

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.utils import to_categorical
import keras.backend as K
from keras.callbacks import EarlyStopping

# %%
K.clear_session()

# %%
model = Sequential()
model.add(Dense(16, input_shape=(64,), activation='relu'))
model.add(Dense(10, activation='softmax'))
model.compile('adam', 'categorical_crossentropy', metrics=['accuracy'])

# %%
# store the initial random weights, we want to start with the same weights every time
initial_weights = model.get_weights()

# %%
y_cat = to_categorical(y, 10)

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y_cat,
                                                    test_size=0.3)

# %%
X_train.shape
# Out:
# (1257, 64)

# %%
train_sizes = (len(X_train) * np.linspace(0.1, 0.999, 4)).astype(int)
train_sizes
# Out:
# array([ 125,  502,  879, 1255])

# %%
train_scores = []
test_scores = []

for train_size in train_sizes:
    X_train_frac, _, y_train_frac, _ = \
    train_test_split(X_train, y_train, train_size=train_size)
    
    # at each iteration reset the weights of the model
    # to the initial random weights
    model.set_weights(initial_weights)
    
    h = model.fit(X_train_frac, y_train_frac,
                  verbose=0,
                  epochs=300,
                  callbacks=[EarlyStopping(monitor='loss', patience=1)])

    r = model.evaluate(X_train_frac, y_train_frac, verbose=0)
    train_scores.append(r[-1])
    
    e = model.evaluate(X_test, y_test, verbose=0)
    test_scores.append(e[-1])
    
    print("Done size: ", train_size)
# Out:
# Done size:  125
# Done size:  502
# Done size:  879
# Done size:  1255

# %%
plt.plot(train_sizes, train_scores, 'o-', label="Training score")
plt.plot(train_sizes, test_scores, 'o-', label="Test score")
plt.legend(loc="best")

# %% [markdown]
# ## Batch Normalization

# %%
from keras.layers import BatchNormalization

# %%
def repeated_training(X_train,
                      y_train,
                      X_test,
                      y_test,
                      units=512,
                      activation='sigmoid',
                      optimizer='sgd',
                      do_bn=False,
                      epochs=10,
                      repeats=3):
    histories = []
    
    for repeat in range(repeats):
        K.clear_session()

        model = Sequential()
        
        # first fully connected layer
        model.add(Dense(units,
                        input_shape=X_train.shape[1:],
                        kernel_initializer='normal',
                        activation=activation))
        if do_bn:
            model.add(BatchNormalization())

        # second fully connected layer
        model.add(Dense(units,
                        kernel_initializer='normal',
                        activation=activation))
        if do_bn:
            model.add(BatchNormalization())

        # third fully connected layer
        model.add(Dense(units,
                        kernel_initializer='normal',
                        activation=activation))
        if do_bn:
            model.add(BatchNormalization())

        # output layer
        model.add(Dense(10, activation='softmax'))
        
        model.compile(optimizer,
                      'categorical_crossentropy',
                      metrics=['accuracy'])

        h = model.fit(X_train, y_train,
                      validation_data=(X_test, y_test),
                      epochs=epochs,
                      verbose=0)
        histories.append([h.history['acc'], h.history['val_acc']])
        print(repeat, end=' ')

    histories = np.array(histories)
    
    # calculate mean and standard deviation across repeats:
    mean_acc = histories.mean(axis=0)
    std_acc = histories.std(axis=0)
    print()
    
    return mean_acc[0], std_acc[0], mean_acc[1], std_acc[1]

# %%
mean_acc, std_acc, mean_acc_val, std_acc_val = \
    repeated_training(X_train, y_train, X_test, y_test, do_bn=False)
# Out:
# 0 1 2

# %%
mean_acc_bn, std_acc_bn, mean_acc_val_bn, std_acc_val_bn = \
    repeated_training(X_train, y_train, X_test, y_test, do_bn=True)
# Out:
# 0 1 2

# %%
def plot_mean_std(m, s):
    plt.plot(m)
    plt.fill_between(range(len(m)), m-s, m+s, alpha=0.1)

# %%
plot_mean_std(mean_acc, std_acc)
plot_mean_std(mean_acc_val, std_acc_val)
plot_mean_std(mean_acc_bn, std_acc_bn)
plot_mean_std(mean_acc_val_bn, std_acc_val_bn)
plt.ylim(0, 1.01)
plt.title("Batch Normalization Accuracy")
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend(['Train', 'Test', 'Train with Batch Normalization', 'Test with Batch Normalization'], loc='best')

# %% [markdown]
# ## Weight Regularization & Dropout

# %%
from keras.layers import Dropout

# %%
model = Sequential()
model.add(Dropout(0.2, input_shape=X_train.shape[1:]))
# first fully connected layer
model.add(Dense(512, kernel_initializer='normal',
                kernel_regularizer='l2', activation='sigmoid'))
model.add(Dropout(0.4)) # fractions to drop, 
model.add(Dense(10, activation='softmax'))

model.compile('sgd',
              'categorical_crossentropy',
              metrics=['accuracy'])

# %% [markdown]
# ## Data augmentation

# %%
from keras.preprocessing.image import ImageDataGenerator

generator = ImageDataGenerator(rescale = 1./255,
                               width_shift_range=0.1,
                               height_shift_range=0.1,
                               rotation_range = 20,
                               shear_range = 0.3,
                               zoom_range = 0.3,
                               horizontal_flip = True)

# %%
# when data does not fit in RAM
train = generator.flow_from_directory('../data/generator',
                                      target_size = (128, 128),
                                      batch_size = 32,
                                      class_mode = 'binary')
# Out:
# Found 1 images belonging to 1 classes.

# %%
plt.figure(figsize=(12, 12))
for i in range(16):
    img, label = train.next()
    plt.subplot(4, 4, i+1)
    plt.imshow(img[0])

# %% [markdown]
# ## Embeddings

# %%
from keras.layers import Embedding

# %%
model = Sequential()
model.add(Embedding(input_dim=100, output_dim=2))
model.compile(loss='binary_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_1 (Embedding)      (None, None, 2)           200
# =================================================================
# Total params: 200
# Trainable params: 200
# Non-trainable params: 0
# _________________________________________________________________

# %%
emb = model.predict(np.array([[81,  1, 96, 79],
                              [17, 47, 69, 50],
                              [49,  3, 12, 88]]))

# %%
emb.shape
# Out:
# (3, 4, 2)

# %%
emb, emb.shape # each value has 2 numbers
# Out:
# (array([[[-0.04640093,  0.01446212],
#          [ 0.01804538, -0.0199042 ],
#          [-0.03081673, -0.04601027],
#          [ 0.02227861, -0.00704562]],
#
#         [[ 0.01993128, -0.0046377 ],
#          [-0.0162037 ,  0.02851576],
#          [-0.01007564, -0.00349175],
#          [ 0.04118248,  0.01003296]],
#
#         [[-0.02240901, -0.02703412],
#          [ 0.00685124,  0.01303321],
#          [ 0.02876284,  0.02638639],
#          [-0.02246163, -0.04485586]]], dtype=float32), (3, 4, 2))

# %% [markdown]
# ## Sentiment prediction on movie Reviews

# %%
from keras.datasets import imdb
# Out:
# Using TensorFlow backend.

# %%
(X_train, y_train), (X_test, y_test) = imdb.load_data('/tmp/imdb.npz',
                                                      num_words=None,
                                                      skip_top=0,
                                                      maxlen=None,
                                                      start_char=1,
                                                      oov_char=2,
                                                      index_from=3)

# %%
X_train.shape
# Out:
# (25000,)

# %%
print(X_train[1]) # already into an embedding
# Out:
# [1, 194, 1153, 194, 8255, 78, 228, 5, 6, 1463, 4369, 5012, 134, 26, 4, 715, 8, 118, 1634, 14, 394, 20, 13, 119, 954, 189, 102, 5, 207, 110, 3103, 21, 14, 69, 188, 8, 30, 23, 7, 4, 249, 126, 93, 4, 114, 9, 2300, 1523, 5, 647, 4, 116, 9, 35, 8163, 4, 229, 9, 340, 1322, 4, 118, 9, 4, 130, 4901, 19, 4, 1002, 5, 89, 29, 952, 46, 37, 4, 455, 9, 45, 43, 38, 1543, 1905, 398, 4, 1649, 26, 6853, 5, 163, 11, 3215, 10156, 4, 1153, 9, 194, 775, 7, 8255, 11596, 349, 2637, 148, 605, 15358, 8003, 15, 123, 125, 68, 23141, 6853, 15, 349, 165, 4362, 98, 5, 4, 228, 9, 43, 36893, 1157, 15, 299, 120, 5, 120, 174, 11, 220, 175, 136, 50, 9, 4373, 228, 8255, 5, 25249, 656, 245, 2350, 5, 4, 9837, 131, 152, 491, 18, 46151, 32, 7464, 1212, 14, 9, 6, 371, 78, 22, 625, 64, 1382, 9, 8, 168, 145, 23, 4, 1690, 15, 16, 4, 1355, 5, 28, 6, 52, 154, 462, 33, 89, 78, 285, 16, 145, 95]

# %%
idx = imdb.get_word_index()

# %%
max(idx.values())
# Out:
# 88584

# %%
idx
# Out:
# {'mina': 50765,
#  'philipp': 87372,
#  'senor': 39782,
#  "53'": 85169,
#  'prakash': 23300,
#  'minidress': 42246,
#  'dredged': 35692,
#  'vietnamese': 10460,
#  'painting': 3367,
#  "surgeon's": 47219,
#  'holmies': 57041,
#  'clueless': 5750,
#  'jetliner': 82584,
#  'lessens': 30096,
#  'utilities\x85': 58004,
#  'badness': 8086,
#  'bravi': 66994,
#  'nez': 76931,
#  'accedes': 59730,
#  'cellach': 32270,
#  'zed': 35685,
#  'databases': 82832,
#  'okej': 59679,
#  'desperations': 66385,
#  'sniffed': 56562,
#  'rowdy': 17552,
#  'giver': 27254,
#  'estate': 3516,
#  'woken': 18802,
#  'giraud': 73363,
#  'icebergs': 38538,
#  "'poverty": 60904,
#  "'jackson'": 60789,
#  "handy's": 63517,
#  'colonizing': 57504,
#  'chomskys': 69629,
#  'arabic': 11128,
#  'outreach': 53358,
#  'chewbacca': 15263,
#  'integral': 9912,
#  'afflictions': 66194,
#  'honkeytonk': 50947,
#  'nah': 14569,
#  'laud': 84361,
#  "lange's": 42181,
#  "'97": 25869,
#  'flubs': 50357,
#  'kitumura': 81701,
#  'flatiron': 41594,
#  'input': 13169,
#  'padme': 50513,
#  'mill': 4206,
#  'gozilla': 66100,
#  'moffat': 32289,
#  'drank': 18904,
#  'powerlessly': 63399,
#  'naaah': 77394,
#  "'split": 51003,
#  'patrice': 55706,
#  'ballsy': 39960,
#  'employment': 10705,
#  'adherent': 76774,
#  'wopat': 34520,
#  'logs': 29913,
#  'dobbs': 37490,
#  'caliber': 4895,
#  'spottiswoode': 61636,
#  'commitments': 15560,
#  'entities': 30690,
#  'fanboys': 21469,
#  "dah'": 83763,
#  'wilfred': 21170,
#  'jaekel': 52048,
#  'taglines': 36555,
#  'velazquez': 79244,
#  'transvestive': 72278,
#  'desilva': 40611,
#  "'poor'": 56882,
#  "cherub's": 78297,
#  'kimmy': 30179,
#  'flowed': 17432,
#  'earthy': 20473,
#  'nazis': 3967,
#  'deportation': 30041,
#  'eschatological': 72137,
#  'move\x85': 78812,
#  'repartee': 20371,
#  'gangster': 2109,
#  'steering': 21132,
#  "pax's": 83879,
#  'direstion': 78299,
#  'hypocrite': 18294,
#  'hee': 14014,
#  'baitz': 53544,
#  'astin': 24629,
#  'bingen': 71249,
#  'leaps\x85': 66380,
#  'gungans': 60202,
#  'acting\x85': 47420,
#  "hadley's": 25271,
#  'vendors': 68358,
#  'trueheart': 43928,
#  'mandibles': 63295,
#  "decade's": 39421,
#  'mst3000': 23271,
#  'iqs': 49896,
#  'drainage': 77420,
#  'placards': 86211,
#  'balkan': 20090,
#  'interestedly': 73211,
#  'equestrian': 47580,
#  'sculpted': 36871,
#  'overington': 42035,
#  "eachother's": 68133,
#  'hastily': 14447,
#  'begining': 26352,
#  'seductiveness': 55550,
#  "hagarty's": 63808,
#  'salvation': 6314,
#  'unrelievedly': 68921,
#  'pirates': 6984,
#  'trait': 11141,
#  'andersons': 47704,
#  "winch'": 52684,
#  'irresponsible': 9120,
#  '230lbs': 80955,
#  'primordial': 29007,
#  "jeffery's": 58795,
#  '¨by': 65289,
#  'scrounges': 86670,
#  'splat': 27600,
#  'retailers': 68482,
#  'evergreen': 15348,
#  'pruning': 39176,
#  'provision': 67059,
#  'monoliths': 57480,
#  'plinky': 74280,
#  'oooomph': 55790,
#  'della': 8609,
#  'srathairn': 63288,
#  'presumbably': 62139,
#  'crimefighting': 73914,
#  '\uf0b7': 24008,
#  'inbreds': 42084,
#  'izes': 86661,
#  'protagonist': 2308,
#  'sloppy': 3781,
#  'wounder': 45436,
#  "pelle's": 86744,
#  'revitalize': 38956,
#  'bunks': 43337,
#  'messes': 13249,
#  "matuschek's": 53810,
#  "pilgrimage's": 76834,
#  'pieced': 17557,
#  'irritated': 7934,
#  'purrs': 38221,
#  'razrukha': 72818,
#  'bioterrorism': 41569,
#  'alun': 47842,
#  'grantness': 63553,
#  'cadillacs': 74432,
#  'divorces': 27730,
#  'wiz': 19825,
#  "makhmalbaf's": 35946,
#  'arnaz': 30383,
#  "o'toole": 9884,
#  '1902': 29774,
#  'harasses': 36739,
#  'fbl': 60502,
#  'confrontation': 5124,
#  'wylie': 58260,
#  'chops': 7921,
#  'geeson': 56106,
#  "kose'": 87843,
#  'pubic': 29488,
#  'exclamation': 16465,
#  'cassanova': 42466,
#  'hicksville': 80518,
#  'coulardeau': 21841,
#  "pascoe's": 60329,
#  'proposals': 35141,
#  'morlar': 60598,
#  'weve': 68699,
#  'reanimate': 52456,
#  'weill': 25536,
#  'midsomer': 55162,
#  'marvellous': 9844,
#  'taxfree': 82120,
#  'gymnasium': 26956,
#  'frogs': 17342,
#  'tagged': 15601,
#  'caused': 2161,
#  "o'byrne": 40537,
#  'film\x85her': 56365,
#  'shearmur': 56654,
#  "'delirious'": 34298,
#  "jessie's": 44619,
#  'bechstein': 39606,
#  'facinating': 48140,
#  'moonraker': 36418,
#  'sufferíngs': 71712,
#  'mechanism': 14986,
#  'gruner': 15430,
#  'loooooooooooong': 80592,
#  'lhasa': 38169,
#  'note': 851,
#  'dispatcher': 47572,
#  'uebermensch': 75699,
#  'sanctimonious': 15577,
#  'permissive': 34458,
#  "'chances": 55223,
#  "'tubes": 77551,
#  'focuses': 2676,
#  'gooooooodddd': 81897,
#  "korsmo's": 53768,
#  'talor': 51528,
#  'pantry': 41760,
#  "lyu's": 49247,
#  "cast's": 19712,
#  'shockers': 27686,
#  'devon': 13952,
#  'holocolism': 65918,
#  "rainbow'": 57746,
#  'punter': 77690,
#  'unsuprised': 80495,
#  "com'": 51759,
#  'comanche': 65904,
#  'exposing': 9706,
#  'carryout': 87579,
#  'argonne': 37382,
#  'tenths': 47550,
#  'scrupulously': 29598,
#  'daze': 25908,
#  'rowen': 77583,
#  'doctoral': 34483,
#  'morals': 6722,
#  "mcelwee's": 40801,
#  'bama': 64170,
#  'lifetimes': 35774,
#  "'superthunderstingcar'": 68633,
#  'relive': 13095,
#  'inventinve': 85381,
#  'wimpole': 85388,
#  "past'": 56265,
#  'iréne': 80042,
#  'diol': 41322,
#  'handover': 36959,
#  'athenean': 56667,
#  'brakes': 16972,
#  'plowright': 17309,
#  'juggle': 27460,
#  'licentious': 72831,
#  'dostoyevskian': 65534,
#  "authorities'": 85586,
#  'parati': 87181,
#  'byrds': 47511,
#  'span': 6309,
#  'anniko': 68857,
#  "giamatti's": 82017,
#  'undeserved': 16773,
#  'riot': 5440,
#  'oppression': 11641,
#  'bafflingly': 35368,
#  'greenness': 52559,
#  'nagurski': 37102,
#  "commenter's": 31326,
#  'bouncer': 37394,
#  'structuralism': 59578,
#  'stvs': 71239,
#  'vannet': 60677,
#  'mamie': 15604,
#  "'move'": 80230,
#  'thingamajigs': 65899,
#  'predeccesor': 43106,
#  'niki': 22756,
#  'repertoires': 51385,
#  'takahisa': 73037,
#  'parrish': 36671,
#  'fondles': 40899,
#  'miscarriage': 16747,
#  "'gangs'": 71845,
#  'chronologies': 52951,
#  'thespian': 11790,
#  'redden': 77992,
#  'uncivilized': 48279,
#  'tepid': 9734,
#  "rance's": 52281,
#  'suki': 84752,
#  'overdoes': 18063,
#  'snowmonton': 52448,
#  'justly': 15809,
#  "serling's": 31849,
#  'shyan': 44623,
#  'grazzo': 66163,
#  'nicaragua': 48718,
#  'imposition': 30948,
#  'wadd': 40129,
#  'detection': 21056,
#  'honorable': 9281,
#  'grégoire': 40108,
#  'catalina': 19191,
#  'bills': 8633,
#  'saviours': 47722,
#  "dating'": 64536,
#  "cake'": 36726,
#  'yasuzu': 54427,
#  'ike': 26932,
#  "writing'": 74699,
#  'lacy': 37675,
#  'brooding': 6040,
#  'energize': 61269,
#  'vays': 51947,
#  'awwwwww': 61397,
#  'tweeness': 53622,
#  'beserk': 70262,
#  'edwrad': 58926,
#  "zeman's": 47883,
#  'lahaye': 47643,
#  'parent': 4066,
#  'cinematoraphy': 55958,
#  "rooneys'": 49525,
#  'construed': 21365,
#  'synths': 46264,
#  'starewicz': 24560,
#  "kermit's": 33967,
#  'holton': 52742,
#  'vfcc': 82527,
#  'gamblers': 19986,
#  'lockers': 26270,
#  'disillusioned': 12534,
#  'immaturely': 81469,
#  'distress': 6713,
#  'zhv': 54945,
#  'information': 1615,
#  'bowled': 26230,
#  "vicious'": 63625,
#  'rochon': 13010,
#  'bashfully': 64245,
#  'climbing': 7609,
#  'elaborate': 3758,
#  'garbled': 20894,
#  'firsts': 71033,
#  '10x': 44242,
#  "parrot's": 56121,
#  'dreichness': 62939,
#  'gröllmann': 82079,
#  'theathre': 71029,
#  'happen': 590,
#  "'panda'": 64451,
#  'foolishness': 18420,
#  'surrogated': 52843,
#  'foree': 17067,
#  "bronstein's": 59732,
#  'excell': 68668,
#  'it´sso': 82666,
#  'ld': 48880,
#  "'art": 24138,
#  'acetylene': 78121,
#  'fnnish': 71881,
#  "demônio'": 77622,
#  'oblique': 26329,
#  'autumnal': 88402,
#  'stepchildren': 63248,
#  'shand': 60805,
#  'adriano': 37460,
#  'marker': 18427,
#  'represents': 3418,
#  'shah': 7926,
#  'fate\x97first': 53513,
#  'relegates': 63154,
#  'binds': 27521,
#  'yonekura': 34903,
#  'lmotp': 36852,
#  'enmity': 63803,
#  'beanpoles': 82793,
#  'aranoa': 38645,
#  "payal's": 53342,
#  'aankh': 60211,
#  "'doll'": 74252,
#  "'eureka": 65571,
#  'zomg': 87798,
#  'santas': 39083,
#  'fwd': 69343,
#  "individual's": 19268,
#  'gilberts': 52631,
#  'unceremoniously': 21347,
#  'spearheaded': 35603,
#  'overcome': 3080,
#  'laurentis': 79860,
#  "'telly": 73696,
#  'waalkes': 51393,
#  'tenets': 28128,
#  'prefect': 35979,
#  'affiliation': 29927,
#  'loki': 53508,
#  'hamburg': 14092,
#  'loudmouthed': 41532,
#  "saint'": 44036,
#  'pub': 8605,
#  'eavesdrops': 72654,
#  'melo': 49212,
#  'uncannily': 29419,
#  'torrences': 66238,
#  'aire': 75846,
#  'bikinis': 18665,
#  'c3po': 22407,
#  'sato': 23284,
#  'guffaws': 30564,
#  'says': 557,
#  'unbelieveablity': 72481,
#  'jereone': 76098,
#  'shikhar': 48679,
#  'excommunicated': 32977,
#  'gibbering': 50606,
#  'heroins': 54658,
#  'politeness': 38038,
#  'thing\x85': 64851,
#  "verite'": 56533,
#  'decongestant': 83642,
#  'sheath': 71964,
#  'feeding': 5792,
#  'dew': 77510,
#  'reprising': 11763,
#  'peters': 5035,
#  'estela': 38619,
#  'kovacs': 13927,
#  'guernsey': 25035,
#  'proliferating': 43124,
#  'archiev': 57612,
#  'orgazim': 64514,
#  'wound': 4526,
#  'operations': 11208,
#  'unedifying': 65003,
#  'ralli': 27944,
#  'lecturer': 20398,
#  'unengaged': 51834,
#  "cahill's": 27962,
#  'river': 1869,
#  'grad': 19291,
#  '\x85right\x85': 82805,
#  "'snappy'": 87114,
#  "wachowski's": 30952,
#  'tc': 39379,
#  'definitively': 21088,
#  "tatum's": 42345,
#  'struts': 25671,
#  'rapport': 14661,
#  'ironclad': 36059,
#  'tio': 69429,
#  'chokeslammed': 78042,
#  'consistency': 10685,
#  'impetus': 21189,
#  'bile': 27898,
#  'keenan': 18476,
#  'sellars': 48614,
#  'pakistanis': 23718,
#  'doff': 82746,
#  'badman': 71290,
#  'mbb': 70629,
#  "swordsman'": 57006,
#  'zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzz': 56866,
#  'hysterics': 15332,
#  'tegan': 53163,
#  'psychic': 4876,
#  'meloni': 19640,
#  'swathe': 42168,
#  'screwy': 35303,
#  "andress'": 66713,
#  'recasted': 79312,
#  'tempt': 21136,
#  'gleason': 12288,
#  'pluto': 17359,
#  'colonel’s': 87293,
#  "miners'": 54529,
#  'uphold': 27616,
#  'retirony': 65194,
#  'eng': 59747,
#  'clearence': 56624,
#  'unequally': 83485,
#  'tasteful': 10012,
#  'theres': 21137,
#  'caprios': 71838,
#  'budge': 35439,
#  'bloodwaters': 52786,
#  'novelette': 45451,
#  'negro': 21196,
#  "kate's": 14344,
#  'sakamoto': 22510,
#  'ugliest': 15958,
#  'painfull': 54745,
#  "stranger's": 48459,
#  'invalidity': 72886,
#  'databanks': 52646,
#  'hoosiers': 51014,
#  'loooove': 78031,
#  'tristain': 31395,
#  "autumn's": 60472,
#  'clackity': 73388,
#  "program's": 32070,
#  "titanic's": 28928,
#  'sweetums': 56424,
#  'testicularly': 67193,
#  "gilmore's": 31050,
#  'comical\x85': 74067,
#  'gorillas': 30007,
#  'druggy': 83448,
#  'inflict': 15194,
#  "could't": 65426,
#  'nepali': 47449,
#  'luting': 71380,
#  'door': 1309,
#  'miou': 19643,
#  'magnum': 11643,
#  'fanatically': 31614,
#  'breakouts': 65623,
#  'tightens': 39027,
#  'sette': 40821,
#  'probally': 71430,
#  'misogynists': 42767,
#  'omega': 11567,
#  'scholars': 14590,
#  "amber's": 50378,
#  'gaiety': 34778,
#  'skye': 18659,
#  "kareeena's": 86252,
#  'bally': 50814,
#  "rea's": 22766,
#  'searcy': 35938,
#  'valentinov': 31430,
#  'ladiesman': 53337,
#  'fingernails': 13468,
#  'sedaris': 76975,
#  "'released'": 76591,
#  'almghandi': 45793,
#  "'kaufman": 53062,
#  'louiguy': 53037,
#  'apolitical': 43122,
#  'timeliness': 82983,
#  'zack': 13085,
#  'oysters': 64415,
#  'ugghh': 79222,
#  "'sister": 31102,
#  'ferengi': 63638,
#  'heron': 46956,
#  'tromeo': 71242,
#  'darshan': 25896,
#  "genie's": 88495,
#  'tavernier': 52212,
#  'puleeze': 58006,
#  'tully': 13558,
#  'ridiculed': 14754,
#  'biographers': 51077,
#  'mallow': 62794,
#  "treatment's": 74663,
#  'cloyingly': 63682,
#  'acrobat': 29730,
#  "'blackboard": 61747,
#  'lemarit': 67333,
#  'satterfield': 58677,
#  "perabo's": 84817,
#  "qi's": 64204,
#  "chimp's": 66196,
#  'coasts': 34639,
#  'bluff': 23114,
#  'unnerving': 8893,
#  'toothpaste': 38599,
#  'hawthorne': 21775,
#  "'soylent": 55360,
#  'copping': 26985,
#  'footraces': 70471,
#  'highbrows': 83621,
#  'circuitous': 56075,
#  'jaundiced': 35408,
#  'explain': 1257,
#  'hilarities': 86501,
#  "so'": 61112,
#  'zara': 26895,
#  "preminger's": 13229,
#  'flavia': 7543,
#  'etching': 49293,
#  "servo's": 72857,
#  'film’s': 45845,
#  'millennial': 48277,
#  'breastfeeding': 65150,
#  'mourning': 9514,
#  'nifty': 8736,
#  'amuse': 10065,
#  'lothar': 48190,
#  'respective': 5486,
#  'barrett': 14358,
#  'perfomances': 54366,
#  'residency': 26166,
#  'ooops': 35010,
#  'château': 20425,
#  "jonathan's": 47685,
#  'comicon': 81873,
#  'batmobile': 16767,
#  'pffffft': 61092,
#  'china': 2711,
#  'gluing': 78068,
#  'begotten': 31639,
#  'ozkan': 71607,
#  'cohen': 6909,
#  'renault': 65377,
#  'oui\x85': 55962,
#  'arent': 38048,
#  "'antigone'": 84827,
#  'animalplanet': 55073,
#  'libbing': 39956,
#  'ribbing': 33521,
#  'dialed': 83454,
#  'swoony': 58543,
#  'ambiguous\x96the': 54828,
#  'withdraws': 30513,
#  "fernando's": 54063,
#  'strayer': 24882,
#  "blunt's": 46661,
#  'dirossario': 61497,
#  'childe': 52279,
#  'pliskin': 86268,
#  'herr': 21099,
#  'introvert': 22570,
#  'schramm': 31528,
#  'toyed': 32728,
#  'qi': 19767,
#  'korty': 51504,
#  "'deliver": 59435,
#  "stargaard's": 55518,
#  'sooon': 71732,
#  'vaunted': 42013,
#  'brough': 85025,
#  'vandalized': 37417,
#  'jegede': 65952,
#  'partanna': 31490,
#  "'face": 51348,
#  'gatiss': 36402,
#  'interlude': 13722,
#  'mills': 8895,
#  'classicists': 44593,
#  'silas': 24090,
#  'positions': 9772,
#  'horrorfilm': 55068,
#  'gummo': 30044,
#  "'x": 39322,
#  'elmer': 9416,
#  "firekeep's": 82260,
#  "monologues'": 68977,
#  'fuher': 46151,
#  'unwelcomed': 41013,
#  'yannis': 66656,
#  'helumis': 72485,
#  'marlins': 75189,
#  'ophuls': 53355,
#  'pitcher': 13019,
#  'sister': 796,
#  'wrinklies': 46767,
#  "melies'": 53286,
#  "keital's": 71116,
#  'nooks': 64800,
#  'ericka': 62799,
#  'bandalier': 82568,
#  'inhaled': 37062,
#  'invalidate': 62626,
#  'ungifted': 68165,
#  'iordache': 71468,
#  'knitting': 25886,
#  'cortese': 45533,
#  'hillard': 45823,
#  "'beckham'": 83687,
#  'milhalovitch': 35172,
#  'wushu': 59759,
#  'unnerve': 46514,
#  'sexless': 23751,
#  'susceptible': 24710,
#  'donation': 22767,
#  'satires': 15547,
#  'epitaph': 75008,
#  "a'hunting": 52433,
#  'gallico': 22592,
#  'yuan': 85725,
#  'jami': 74881,
#  'filmes': 60702,
#  'bordered': 19972,
#  "stallone's": 12203,
#  "akshay's": 28284,
#  'slag': 49577,
#  'raksin': 57433,
#  'latine': 59253,
#  'lifeguard': 48725,
#  'gadabout': 75246,
#  'map': 4908,
#  'tenderizer': 59620,
#  'decoding': 62047,
#  'latecomer': 41245,
#  'examp': 73895,
#  'widowed': 7329,
#  'osmosis': 87737,
#  'parters': 34607,
#  'aggelopoulos': 61635,
#  'thursdays': 41227,
#  'bitchin': 70669,
#  'tragidian': 72593,
#  "'welcome'": 57498,
#  'defused': 48682,
#  'inserting': 14139,
#  'begin\x85': 53667,
#  'vaudeville': 8632,
#  'selve': 68494,
#  'potboiler': 15400,
#  'reptile': 17728,
#  'enzo': 27477,
#  "'woodstock'": 60790,
#  'naysay': 57467,
#  'massachusett': 72867,
#  "rex'": 45622,
#  "s2t's": 69115,
#  'minamoto': 55506,
#  'haenel': 24268,
#  'preacher': 8821,
#  'mindwalk': 65886,
#  'dtr': 70599,
#  'zacharias': 38135,
#  'konerak': 53349,
#  'eréndira': 81367,
#  'wurman': 44379,
#  'reliquary': 74414,
#  'failed': 1193,
#  "howlers'": 82249,
#  "loomis'": 75515,
#  'unplug': 61780,
#  'ascertain': 19212,
#  "beavers'": 64148,
#  'jerilderie': 40730,
#  'jarvis': 21156,
#  'calvin': 11559,
#  'fantasia': 28714,
#  'atc': 55869,
#  "d'abo's": 42595,
#  'recipients': 41455,
#  'soba': 77644,
#  'theodorakis': 45196,
#  'planck': 77234,
#  'sperm': 16766,
#  'postlesumthingor': 54799,
#  'wrote': 1037,
#  'naif': 41821,
#  "diana's": 32244,
#  'widdle': 67485,
#  'francessca': 82548,
#  'logistics': 50735,
#  'winchester': 5826,
#  "party's": 51364,
#  'farsi': 39684,
#  'flavin': 48676,
#  "colony's": 42068,
#  'lubricated': 88566,
#  'bhavtakur': 65443,
#  'wahlberg': 15460,
#  'uninfected': 76632,
#  'taps': 16843,
#  'into': 80,
#  'ate': 9942,
#  'imperialism': 23906,
#  'shoot\x97': 67168,
#  'excepting': 20466,
#  "biggie's": 40813,
#  'accomplice': 12887,
#  'sheen': 7280,
#  'praying': 9920,
#  'shirt': 3735,
#  "'maiden": 83378,
#  'radziwill': 52879,
#  'sheets\x97what': 66444,
#  'tantrum': 22829,
#  'emilfork': 52677,
#  'indiscretionary': 62732,
#  'tawa': 44371,
#  'ibéria': 53860,
#  "factory's": 54270,
#  'unsexy': 34851,
#  "'schindler's": 44584,
#  'clamour': 81165,
#  'murdering': 5327,
#  'boringly': 17514,
#  'family\x85': 74135,
#  'schoolbus': 85242,
#  'bubbas': 45952,
#  "'river": 47981,
#  'quoi': 45708,
#  'dough': 13989,
#  'pronounce': 13032,
#  'sensors': 56394,
#  'earl': 4872,
#  'diffuses': 72040,
#  'paranoiac': 28504,
#  'rampant': 7873,
#  'rino': 32767,
#  'swedlow': 72506,
#  'se': 7826,
#  'velez': 77249,
#  'insides': 23693,
#  'adheres': 28786,
#  'legros': 49799,
#  'affectts': 67913,
#  "harpo's": 40831,
#  'silicone': 20742,
#  'hodet': 53485,
#  'wouldn': 39964,
#  'farra': 74974,
#  'snubs': 67754,
#  'penned': 7713,
#  'spotlighted': 72772,
#  'sings': 3139,
#  'boxcover': 51727,
#  'supermarionation': 33463,
#  'ichikawa': 37205,
#  'subcharacters': 58007,
#  'lange': 9507,
#  'vacuums': 57417,
#  'puppetmaster': 79536,
#  'courteney': 41826,
#  'cockiness': 38632,
#  'ayesha': 26313,
#  'maga': 72422,
#  'foreshortened': 62297,
#  'similarities': 4348,
#  'colored': 6591,
#  'dirth': 52509,
#  'impersonating': 12233,
#  'turntable': 39928,
#  'malle': 24035,
#  'strippers': 14470,
#  'smirking': 21345,
#  'yograj': 66807,
#  'bagdad': 9958,
#  'crunch': 27092,
#  'laundered': 42030,
#  'southerner': 24740,
#  'fork': 15324,
#  "cloud's": 62677,
#  "yalom's": 45602,
#  'exhilarating': 10264,
#  'vida': 18824,
#  'comtemporary': 70902,
#  'exaggerative': 57373,
#  "o'ross": 66314,
#  'hour\x85and': 61977,
#  'edgiest': 52165,
#  'plugged': 25724,
#  'chignon': 69485,
#  'profiler': 32430,
#  'novocain': 85459,
#  "cal's": 35248,
#  'huber': 86374,
#  "interpretor'": 82998,
#  "ed's": 22803,
#  'grandest': 29467,
#  'forty': 4209,
#  '22d': 68177,
#  'noble': 3140,
#  'sophomoronic': 68272,
#  "'lady": 62650,
#  'voogdt': 44765,
#  "s'est": 48738,
#  'greetings': 13904,
#  'mourikis': 77951,
#  'hightly': 73685,
#  'afore': 17925,
#  'lunacies': 67905,
#  'atoll': 38450,
#  'mccallister': 45738,
#  "1995's": 41513,
#  "o'donnell": 17832,
#  'streamed': 48047,
#  'aggravation': 31554,
#  "ab's": 47651,
#  'effette': 52309,
#  'cramden': 85774,
#  "serve'": 86952,
#  'villan': 35437,
#  'takeaway': 74501,
#  'parcel': 30413,
#  'haunt': 7367,
#  'ac': 31154,
#  'rudd': 9073,
#  'gritting': 35386,
#  'investigates': 10903,
#  'pushy': 23204,
#  'ponderous': 11161,
#  'muriël': 37816,
#  'grrrrrr': 73758,
#  'granite': 43182,
#  'milling': 40491,
#  '2000ad': 59429,
#  'pharoah': 38011,
#  'hitcher': 40202,
#  "snobs'": 57044,
#  "thierry's": 71093,
#  'aires': 28524,
#  'plagiarism': 18019,
#  "lin's": 85589,
#  'monde': 46571,
#  'yearn': 13909,
#  'georgetown': 37529,
#  'biochemical': 50995,
#  'seam': 25408,
#  "k'sun": 18983,
#  'ru': 49138,
#  'doors': 3591,
#  'adroitly': 39308,
#  'freshened': 86588,
#  'koi': 59231,
#  "berkoff's": 38482,
#  'secretly': 4546,
#  'almoust': 83028,
#  'planned': 4258,
#  'roehler': 59129,
#  'shepis': 34901,
#  "'wanna": 41160,
#  'loopy': 17722,
#  "cameroun's": 75623,
#  'delany': 34139,
#  'bnl': 31616,
#  'festivals': 7254,
#  "'depraved'": 70941,
#  'hordes': 12414,
#  'unconfident': 69878,
#  'gervais': 20900,
#  'grandness': 43932,
#  'descendant': 14855,
#  'stripes': 11599,
#  'minny': 71962,
#  'vajna': 84834,
#  'landing\x85': 75275,
#  'pelle': 64177,
#  'newswoman': 75497,
#  'unneeded': 19753,
#  'wormwood': 42630,
#  "armitage's": 60151,
#  'pufnstuff': 40306,
#  'declines': 21078,
#  'deadwood': 22951,
#  'birthplace': 19051,
#  'steadily': 12778,
#  "'touching": 57530,
#  'authoress': 35752,
#  'slutty': 11441,
#  'demonisation': 61165,
#  'protags': 52135,
#  'gaddis': 77901,
#  'moon': 1881,
#  'meted': 43117,
#  'crafting': 18347,
#  "healy's": 60883,
#  'quoting': 10107,
#  'wilkie': 51034,
#  'morrisette': 37555,
#  'nandani': 73380,
#  'inacessible': 85769,
#  'waaaaaaaaay': 72273,
#  'assembled': 6535,
#  'involuntarily': 37419,
#  "schmitz's": 76490,
#  'seyrig': 56721,
#  'supermans': 37894,
#  'spark': 5368,
#  'skyscraper': 30308,
#  'calcifying': 83455,
#  'abandonment': 15140,
#  'elisa': 41738,
#  'eponymous': 9803,
#  'longstreet': 37356,
#  'perspectives': 8350,
#  'mendoza': 46698,
#  'midway': 10815,
#  'hick': 10532,
#  "madhavi's": 48138,
#  'sonali': 32269,
#  "audiard's": 27264,
#  'fetched': 4187,
#  "straight's": 39225,
#  "'sleeper'": 55426,
#  'swinging': 7027,
#  'twisting': 11314,
#  'jesus': 1951,
#  'tagawa': 43397,
#  "p'tite": 55532,
#  'succeeded': 4099,
#  'skedaddle': 85485,
#  'sulfurous': 79216,
#  "'airplane'": 43520,
#  'robins': 61358,
#  'unawareness': 84683,
#  'circumstance': 10168,
#  'sevillanas': 85971,
#  'dixton': 81415,
#  'tajiri': 87922,
#  'vorelli': 84946,
#  'werent': 41935,
#  ...}

# %%
# swap keys and values
rev_idx = {v+3:k for k,v in idx.items()}

# %%
rev_idx[4]
# Out:
# 'the'

# %%
rev_idx[0] = 'padding_char'
rev_idx[1] = 'start_char'
rev_idx[2] = 'oov_char'
rev_idx[3] = 'unk_char'

# %%
rev_idx[3]
# Out:
# 'unk_char'

# %%
y_train[0]
# Out:
# 1

# %%
example_review = ' '.join([rev_idx[word] for word in X_train[0]])
example_review # gets a review
# Out:
# "start_char this film was just brilliant casting location scenery story direction everyone's really suited the part they played and you could just imagine being there robert redford's is an amazing actor and now the same being director norman's father came from the same scottish island as myself so i loved the fact there was a real connection with this film the witty remarks throughout the film were great it was just brilliant so much that i bought the film as soon as it was released for retail and would recommend it to everyone to watch and the fly fishing was amazing really cried at the end it was so sad and you know what they say if you cry at a film it must have been good and this definitely was also congratulations to the two little boy's that played the part's of norman and paul they were just brilliant children are often left out of the praising list i think because the stars that play them all grown up are such a big profile for the whole film but these children are amazing and should be praised for what they have done don't you think the whole story was so lovely because it was true and was someone's life after all that was shared with us all"

# %%
# our reviews have different length
len(X_train[0])
# Out:
# 218

# %%
len(X_train[1])
# Out:
# 189

# %%
len(X_train[2])
# Out:
# 141

# %%
len(X_train[3])
# Out:
# 550

# %%
from keras.preprocessing.sequence import pad_sequences
from keras.layers import LSTM

# %%
maxlen = 100

# we padd the sequences with zeroes and maximum length, pre or post padding
X_train_pad = pad_sequences(X_train, maxlen=maxlen)
X_test_pad = pad_sequences(X_test, maxlen=maxlen)

# %%
X_train_pad.shape
# Out:
# (25000, 100)

# %%
X_train_pad[0]
# Out:
# array([ 1415,    33,     6,    22,    12,   215,    28,    77,    52,
#            5,    14,   407,    16,    82, 10311,     8,     4,   107,
#          117,  5952,    15,   256,     4, 31050,     7,  3766,     5,
#          723,    36,    71,    43,   530,   476,    26,   400,   317,
#           46,     7,     4, 12118,  1029,    13,   104,    88,     4,
#          381,    15,   297,    98,    32,  2071,    56,    26,   141,
#            6,   194,  7486,    18,     4,   226,    22,    21,   134,
#          476,    26,   480,     5,   144,    30,  5535,    18,    51,
#           36,    28,   224,    92,    25,   104,     4,   226,    65,
#           16,    38,  1334,    88,    12,    16,   283,     5,    16,
#         4472,   113,   103,    32,    15,    16,  5345,    19,   178,    32], dtype=int32)

# %%
X_train[0]
# Out:
# [1,
#  14,
#  22,
#  16,
#  43,
#  530,
#  973,
#  1622,
#  1385,
#  65,
#  458,
#  4468,
#  66,
#  3941,
#  4,
#  173,
#  36,
#  256,
#  5,
#  25,
#  100,
#  43,
#  838,
#  112,
#  50,
#  670,
#  22665,
#  9,
#  35,
#  480,
#  284,
#  5,
#  150,
#  4,
#  172,
#  112,
#  167,
#  21631,
#  336,
#  385,
#  39,
#  4,
#  172,
#  4536,
#  1111,
#  17,
#  546,
#  38,
#  13,
#  447,
#  4,
#  192,
#  50,
#  16,
#  6,
#  147,
#  2025,
#  19,
#  14,
#  22,
#  4,
#  1920,
#  4613,
#  469,
#  4,
#  22,
#  71,
#  87,
#  12,
#  16,
#  43,
#  530,
#  38,
#  76,
#  15,
#  13,
#  1247,
#  4,
#  22,
#  17,
#  515,
#  17,
#  12,
#  16,
#  626,
#  18,
#  19193,
#  5,
#  62,
#  386,
#  12,
#  8,
#  316,
#  8,
#  106,
#  5,
#  4,
#  2223,
#  5244,
#  16,
#  480,
#  66,
#  3785,
#  33,
#  4,
#  130,
#  12,
#  16,
#  38,
#  619,
#  5,
#  25,
#  124,
#  51,
#  36,
#  135,
#  48,
#  25,
#  1415,
#  33,
#  6,
#  22,
#  12,
#  215,
#  28,
#  77,
#  52,
#  5,
#  14,
#  407,
#  16,
#  82,
#  10311,
#  8,
#  4,
#  107,
#  117,
#  5952,
#  15,
#  256,
#  4,
#  31050,
#  7,
#  3766,
#  5,
#  723,
#  36,
#  71,
#  43,
#  530,
#  476,
#  26,
#  400,
#  317,
#  46,
#  7,
#  4,
#  12118,
#  1029,
#  13,
#  104,
#  88,
#  4,
#  381,
#  15,
#  297,
#  98,
#  32,
#  2071,
#  56,
#  26,
#  141,
#  6,
#  194,
#  7486,
#  18,
#  4,
#  226,
#  22,
#  21,
#  134,
#  476,
#  26,
#  480,
#  5,
#  144,
#  30,
#  5535,
#  18,
#  51,
#  36,
#  28,
#  224,
#  92,
#  25,
#  104,
#  4,
#  226,
#  65,
#  16,
#  38,
#  1334,
#  88,
#  12,
#  16,
#  283,
#  5,
#  16,
#  4472,
#  113,
#  103,
#  32,
#  15,
#  16,
#  5345,
#  19,
#  178,
#  32]

# %%
max_features = max([max(x) for x in X_train_pad] + 
                   [max(x) for x in X_test_pad]) + 1
max_features
# Out:
# 88587

# %%
# 1 is positive 0 is negative
y_train
# Out:
# array([1, 0, 0, ..., 0, 1, 0])

# %%
model = Sequential()
model.add(Embedding(max_features, 128))
model.add(LSTM(64, dropout=0.2, recurrent_dropout=0.2))
model.add(Dense(1, activation='sigmoid'))

model.compile(loss='binary_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

# %%
model.fit(X_train_pad, y_train,
          batch_size=32,
          epochs=2,
          validation_split=0.3)
# Out:
# Train on 17500 samples, validate on 7500 samples
# Epoch 1/2
# 17500/17500 [==============================] - 246s - loss: 0.4791 - acc: 0.7694 - val_loss: 0.4044 - val_acc: 0.8176
# Epoch 2/2
# 17500/17500 [==============================] - 234s - loss: 0.2737 - acc: 0.8909 - val_loss: 0.3987 - val_acc: 0.8337

# %%
score, acc = model.evaluate(X_test_pad, y_test)
print('Test score:', score)
print('Test accuracy:', acc)
# Out:
# 25000/25000 [==============================] - 43s
# Test score: 0.408046099243
# Test accuracy: 0.82504

# %% [markdown]
# ## Exercise 1
#
# - Reload the IMDB data keeping only the first 20000 most common words
# - pad the reviews to a shorter length (eg. 70 or 80), this time make sure you keep the first part of the review if it's longer than the maximum length
# - re run the model (remember to set max_features correctly)
# - does it train faster this time?
# - do you get a better performance?

# %% [markdown]
# ## Exercise 2
#
# - Reload the digits data as above
# - define a function repeated_training_reg_dropout that adds regularization and dropout to a fully connected network
# - compare the performance with/witouth dropout and regularization like we did for batch normalization
# - do you get a better performance?

# %% [markdown]
# ## Exercise 3
#
# This is a very long and complex exercise, that should give you an idea of a real world scenario. Feel free to look at the solution if you feel lost. Also, feel free to run this on Floyd with a GPU, in which case you don't need to download the data.
#
# If you are running this locally, download and unpack the male/female pictures from [here](https://www.dropbox.com/s/nov493om2jmh2gp/male_female.tgz?dl=0). These images and labels were obtained from [Crowdflower](https://www.crowdflower.com/data-for-everyone/).
#
# Your goal is to build an image classifier that will recognize the gender of a person from pictures.
#
# - Have a look at the directory structure and inspect a couple of pictures
# - Design a model that will take a color image of size 64x64 as input and return a binary output (female=0/male=1)
# - Feel free to introduce any regularization technique in your model (Dropout, Batch Normalization, Weight Regularization)
# - Compile your model with an optimizer of your choice
# - Using `ImageDataGenerator`, define a train generator that will augment your images with some geometric transformations. Feel free to choose the parameters that make sense to you.
# - Define also a test generator, whose only purpose is to rescale the pixels by 1./255
# - use the function `flow_from_directory` to generate batches from the train and test folders. Make sure you set the `target_size` to 64x64.
# - Use the `model.fit_generator` function to fit the model on the batches generated from the ImageDataGenerator. Since you are streaming and augmenting the data in real time you will have to decide how many batches make an epoch and how many epochs you want to run
# - Train your model (you should get to at least 85% accuracy)
# - Once you are satisfied with your training, check a few of the misclassified pictures. Are those sensible errors?
